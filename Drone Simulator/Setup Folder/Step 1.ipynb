# %% [markdown]
# Install Codrone python Package

# %% [markdown]
# Select the Code Below and Press on Keyboard (Shift + Enter) to run the Code

# %%
pip install codrone-simulator

# %% [markdown]
# If Sucessfull install, you should be able to see text below

# %% [markdown]
# ![image.png](attachment:f796b1bf-479e-48ee-a5f3-eeb53bbaabbb.png)

# %% [markdown]
# -----------------------------------

# %% [markdown]
# Double Check if you sucessfully Installed Codrone Python Package

# %% [markdown]
# Select the Code and Press (Shift + Enter) below to list down all the installed python packages

# %%
pip list

# %% [markdown]
# After Running the code, Find codrone-simulator
